# %%
import cma

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,20))
cma.plot()

# %%
l = cma.CMADataLogger()
l.plot()

# %%
l.data.keys()
# Out:
# dict_keys(['D', 'corrspec', 'f', 'std', 'xmean', 'xrecent'])

# %%
l.data['xrecent']
# Out:
# array([[ 1.00000000e+00,  1.20000000e+01,  8.94950276e-02, ...,
#          1.07344375e+00, -3.49080021e-02,  9.85923982e-01],
#        [ 2.00000000e+00,  2.40000000e+01,  8.24466941e-02, ...,
#          1.08896719e+00, -8.11633893e-04,  1.10783558e+00],
#        [ 3.00000000e+00,  3.60000000e+01,  7.65817205e-02, ...,
#          9.59156250e-01,  9.14440289e-02,  1.08350349e+00],
#        ...,
#        [ 9.70000000e+01,  1.16400000e+03,  1.74652140e-02, ...,
#          1.10997879e+00, -1.93711223e-02,  9.84155812e-01],
#        [ 9.80000000e+01,  1.17600000e+03,  1.70958019e-02, ...,
#          1.10576353e+00, -2.06223654e-02,  9.91730782e-01],
#        [ 9.80000000e+01,  1.24600000e+03,  1.70958019e-02, ...,
#          1.41503289e+00,  1.67994996e-01,  1.14781048e+00]])

# %%
l.data['f'].shape
# Out:
# (98, 8)

# %%
l.plot_all()

# %%
x = [0.0]*20
x[0] = 0.014
x[1] = 1.02
x[2] =
# Out:
# Iterat Nfevals  function value    axis ratio maxstd  minstd
#     1     12 8.10400247573853e-02 1.0e+00 8.98e-02 8.84e-02
#     2     24 6.50082007050514e-02 1.1e+00 8.28e-02 8.02e-02
#   101   1212 3.91226783394814e-02 2.3e+00 2.11e-02 1.44e-02
#   119   1428 6.09253309667110e-02 2.5e+00 2.71e-02 1.54e-02
#   120   1440 5.02407178282738e-02 2.5e+00 2.61e-02 1.47e-02
#   121   1452 4.90086600184441e-02 2.5e+00 2.52e-02 1.42e-02
# Iterat Nfevals  function value    axis ratio maxstd  minstd
#    90   1080 3.84491160511971e-02 2.2e+00 2.71e-02 1.84e-02
